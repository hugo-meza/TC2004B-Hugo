# %%
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris

# %%
df = pd.read_csv("https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv")

# %%
labels = df.loc[:, "variety"]
labels = labels.map({'Setosa': 0, 'Versicolor': 1, 'Virginica': 2}).tolist()
df = df.iloc[:, 0:3]
df
# Out:
#      sepal.length  sepal.width  petal.length
# 0             5.1          3.5           1.4
# 1             4.9          3.0           1.4
# 2             4.7          3.2           1.3
# 3             4.6          3.1           1.5
# 4             5.0          3.6           1.4
# ..            ...          ...           ...
# 145           6.7          3.0           5.2
# 146           6.3          2.5           5.0
# 147           6.5          3.0           5.2
# 148           6.2          3.4           5.4
# 149           5.9          3.0           5.1
#
# [150 rows x 3 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(df, labels, test_size = 0.3, random_state = 42)

clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)


cm = confusion_matrix(y_test, y_pred, labels = clf.classes_)

disp = ConfusionMatrixDisplay(confusion_matrix = cm , display_labels = clf.classes_)
disp.plot(cmap = plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# %%
report = classification_report(y_test, y_pred, labels = clf.classes_)

print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        19
#            1       0.81      1.00      0.90        13
#            2       1.00      0.77      0.87        13
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.92      0.92        45
# weighted avg       0.95      0.93      0.93        45

# %%
plt.figure(figsize=(12,8))
plot_tree(clf, feature_names = df.columns, class_names=clf.classes_, filled = True)
plt.title("Decision Tree Visualitation")
plt.show()

plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=clf.classes_, filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 plot_tree(clf, feature_names=df.columns, class_names=clf.classes_, filled=True)
#       3 plot_tree(clf, feature_names = df.columns, class_names=clf.classes_, filled = True)
#       4 plt.title("Decision Tree Visualitation")
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:215, in plot_tree(decision_tree, max_depth, feature_names, class_names, label, filled, impurity, node_ids, proportion, rounded, precision, ax, fontsize)
#     200 check_is_fitted(decision_tree)
#     202 exporter = _MPLTreeExporter(
#     203     max_depth=max_depth,
#     204     feature_names=feature_names,
#    (...)    213     fontsize=fontsize,
#     214 )
# --> 215 return exporter.export(decision_tree, ax=ax)
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:662, in _MPLTreeExporter.export(self, decision_tree, ax)
#     660 ax.clear()
#     661 ax.set_axis_off()
# --> 662 my_tree = self._make_tree(0, decision_tree.tree_, decision_tree.criterion)
#     663 draw_tree = buchheim(my_tree)
#     665 # important to make sure we're still
#     666 # inside the axis after drawing the box
#     667 # this makes sense because the width of a box
#     668 # is about the same as the distance between boxes
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:646, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     638 name = self.node_to_str(et, node_id, criterion=criterion)
#     639 if et.children_left[node_id] != _tree.TREE_LEAF and (
#     640     self.max_depth is None or depth <= self.max_depth
#     641 ):
#     642     children = [
#     643         self._make_tree(
#     644             et.children_left[node_id], et, criterion, depth=depth + 1
#     645         ),
# --> 646         self._make_tree(
#     647             et.children_right[node_id], et, criterion, depth=depth + 1
#     648         ),
#     649     ]
#     650 else:
#     651     return Tree(name, node_id)
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:643, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     638 name = self.node_to_str(et, node_id, criterion=criterion)
#     639 if et.children_left[node_id] != _tree.TREE_LEAF and (
#     640     self.max_depth is None or depth <= self.max_depth
#     641 ):
#     642     children = [
# --> 643         self._make_tree(
#     644             et.children_left[node_id], et, criterion, depth=depth + 1
#     645         ),
#     646         self._make_tree(
#     647             et.children_right[node_id], et, criterion, depth=depth + 1
#     648         ),
#     649     ]
#     650 else:
#     651     return Tree(name, node_id)
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:638, in _MPLTreeExporter._make_tree(self, node_id, et, criterion, depth)
#     635 def _make_tree(self, node_id, et, criterion, depth=0):
#     636     # traverses _tree.Tree recursively, builds intermediate
#     637     # "_reingold_tilford.Tree" object
# --> 638     name = self.node_to_str(et, node_id, criterion=criterion)
#     639     if et.children_left[node_id] != _tree.TREE_LEAF and (
#     640         self.max_depth is None or depth <= self.max_depth
#     641     ):
#     642         children = [
#     643             self._make_tree(
#     644                 et.children_left[node_id], et, criterion, depth=depth + 1
#    (...)    648             ),
#     649         ]
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\sklearn\tree\_export.py:320, in _BaseTreeExporter.node_to_str(self, tree, node_id, criterion)
#     317 if tree.children_left[node_id] != _tree.TREE_LEAF:
#     318     # Always write node decision criteria, except for leaves
#     319     if self.feature_names is not None:
# --> 320         feature = self.feature_names[tree.feature[node_id]]
#     321         feature = self.str_escape(feature)
#     322     else:
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\pandas\core\indexes\base.py:5401, in Index.__getitem__(self, key)
#    5398 if is_integer(key) or is_float(key):
#    5399     # GH#44051 exclude bool, which would return a 2d ndarray
#    5400     key = com.cast_scalar_indexer(key)
# -> 5401     return getitem(key)
#    5403 if isinstance(key, slice):
#    5404     # This case is separated from the conditional above to avoid
#    5405     # pessimization com.is_bool_indexer and ndim checks.
#    5406     return self._getitem_slice(key)
#
# File ~\Documents\GitHub\TC2004B-Hugo\tc2004b_env\Lib\site-packages\pandas\core\arrays\_mixins.py:293, in NDArrayBackedExtensionArray.__getitem__(self, key)
#     287 def __getitem__(
#     288     self,
#     289     key: PositionalIndexer2D,
#     290 ) -> Self | Any:
#     291     if lib.is_integer(key):
#     292         # fast-path
# --> 293         result = self._ndarray[key]
#     294         if self.ndim == 1:
#     295             return self._box_func(result)
#
# IndexError: index 3 is out of bounds for axis 0 with size 3

# %% [markdown]
# Hay 45 Instances que se pueden observar como support.
#
# En el support podemos ver la class misbalance (

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
url = 'https://gist.githubusercontent.com/netj/8836201/raw/6f9306ad21398ea43cba4f7d537619d0e07d5ae3/iris.csv'

# Cargar el dataset en un DataFrame
data = pd.read_csv(url)
print(data.head())

# Split features and target
X = data.drop('variety', axis=1)
y = data['variety']

# Train/test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize and train Decision Tree classifier
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Predict on test data
y_pred = clf.predict(X_test)

# Confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=clf.classes_)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=clf.classes_)
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.show()

# Classification report
report = classification_report(y_test, y_pred, labels=clf.classes_)
print("Classification Report:")
print(report)

#Visualize decision tree
plt.figure(figsize=(12, 8))
plot_tree(clf, feature_names=X.columns, class_names=clf.classes_, filled=True)
plt.title("Decision Tree Visualization")
plt.show()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa
# Classification Report:
#               precision    recall  f1-score   support
#
#       Setosa       1.00      1.00      1.00        19
#   Versicolor       1.00      1.00      1.00        13
#    Virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
